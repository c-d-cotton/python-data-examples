# %% [markdown]
# # Panel Data

# %% [markdown]
# Can run with statsmodels (and dummies) or linearmodels. Statsmodels seems to be a bit more general but also seems to require you to specify the dummies in each regression you run. Linearmodels is not in basic Anaconda.

# %%
# basic setup
import datetime
from dateutil.relativedelta import relativedelta
from itertools import product
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import pytz
import statsmodels.api as sm
import statsmodels.formula.api as smf
import string
import sys

import linearmodels

# function to create a tabular table
sys.path.append('submodules/python-tabular-output/')
from tab_general_func import tabularconvert
from tab_general_func import mergetabsecs
from tab_sm_func import getcoefftabmatrix
from tab_sm_func import getparamtabmatrix
from tab_sm_func import getsmresultstable

# %% [markdown]
# ## Example Without Linearmodels

# %%
# get dataset:{{{

ni = 10
nt = 1000

# Example of generating random number distribution
# loc = mean, scale = sd, size = array of distribution
x1 = np.random.normal(loc = 0, scale = 1, size = [ni, nt])
epsilon = np.random.normal(loc = 0, scale = 1, size = [ni, nt])

# basic fixed effect
alphai = np.random.normal(loc = 0, scale = 5, size = [ni])
# time trend by entity
gammai = np.random.normal(loc = 0, scale = 0.5, size = [ni])
gammai = [0] * ni

# time fixed effect
gammat = np.random.normal(loc = 0, scale = 5, size = [nt])

y = np.empty([ni, nt])
idi = np.empty([ni, nt])
timet = np.empty([ni, nt])
for i in range(ni):
    for t in range(nt):
        y[i, t] = alphai[i] + gammat[t] + gammai[i] + x1[i, t] + epsilon[i, t]
        idi[i, t] = i
        timet[i, t] = t
# reshape as variables
y = y.reshape(ni * nt)
x1 = x1.reshape(ni * nt)
idi = idi.reshape(ni * nt)
timet = timet.reshape(ni * nt)

dforiginal = pd.DataFrame({'y': y, 'x1': x1, 'id': idi, 'time': timet})
# get dataset:}}}

df = dforiginal

model0 = smf.ols(formula = 'y ~ x1', data = dforiginal).fit()

model1 = smf.ols(formula = 'y ~ x1 + C(time)', data = dforiginal).fit()

model2 = smf.ols(formula = 'y ~ x1 + C(time) + C(id)', data = dforiginal).fit()

# multiplying and including other necessary terms for multiplication with dummy to make sense
model3 = smf.ols(formula = 'y ~ x1 * C(id)', data = dforiginal).fit()
print(model3.summary())

# multiplying but not including other necessary terms for multiplication with dummy to make sense
model4 = smf.ols(formula = 'y ~ x1 : C(id)', data = dforiginal).fit()
print(model4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.336
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     266.2
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):               0.00
# Time:                        14:04:50   Log-Likelihood:                -30420.
# No. Observations:               10000   AIC:                         6.088e+04
# Df Residuals:                    9980   BIC:                         6.102e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           7.2789      0.160     45.357      0.000       6.964       7.594
# C(id)[T.1.0]      -10.3868      0.227    -45.764      0.000     -10.832      -9.942
# C(id)[T.2.0]       -5.2169      0.227    -22.989      0.000      -5.662      -4.772
# C(id)[T.3.0]       -4.1881      0.227    -18.440      0.000      -4.633      -3.743
# C(id)[T.4.0]       -9.3841      0.227    -41.322      0.000      -9.829      -8.939
# C(id)[T.5.0]       -4.7693      0.227    -21.016      0.000      -5.214      -4.324
# C(id)[T.6.0]        1.4056      0.227      6.193      0.000       0.961       1.850
# C(id)[T.7.0]       -2.7710      0.227    -12.206      0.000      -3.216      -2.326
# C(id)[T.8.0]       -3.3918      0.227    -14.947      0.000      -3.837      -2.947
# C(id)[T.9.0]       -6.2134      0.227    -27.380      0.000      -6.658      -5.769
# x1                  0.8972      0.162      5.552      0.000       0.580       1.214
# x1:C(id)[T.1.0]    -0.1547      0.229     -0.675      0.500      -0.604       0.295
# x1:C(id)[T.2.0]     0.0137      0.228      0.060      0.952      -0.434       0.461
# x1:C(id)[T.3.0]     0.0510      0.228      0.223      0.823      -0.397       0.499
# x1:C(id)[T.4.0]     0.5249      0.228      2.300      0.021       0.077       0.972
# x1:C(id)[T.5.0]    -0.1540      0.227     -0.678      0.498      -0.599       0.291
# x1:C(id)[T.6.0]     0.2076      0.228      0.912      0.362      -0.239       0.654
# x1:C(id)[T.7.0]     0.2084      0.230      0.906      0.365      -0.243       0.659
# x1:C(id)[T.8.0]    -0.1217      0.224     -0.542      0.588      -0.562       0.318
# x1:C(id)[T.9.0]     0.2264      0.229      0.990      0.322      -0.222       0.675
# ==============================================================================
# Omnibus:                        8.667   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                9.562
# Skew:                          -0.023   Prob(JB):                      0.00839
# Kurtosis:                       3.144   Cond. No.                         11.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     23.35
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):           5.49e-44
# Time:                        14:04:50   Log-Likelihood:                -32354.
# No. Observations:               10000   AIC:                         6.473e+04
# Df Residuals:                    9989   BIC:                         6.481e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         2.7884      0.062     45.292      0.000       2.668       2.909
# x1:C(id)[0.0]     0.9987      0.196      5.097      0.000       0.615       1.383
# x1:C(id)[1.0]     0.5880      0.197      2.980      0.003       0.201       0.975
# x1:C(id)[2.0]     0.9029      0.196      4.615      0.000       0.519       1.286
# x1:C(id)[3.0]     0.9656      0.195      4.940      0.000       0.582       1.349
# x1:C(id)[4.0]     1.1519      0.195      5.899      0.000       0.769       1.535
# x1:C(id)[5.0]     0.7455      0.193      3.857      0.000       0.367       1.124
# x1:C(id)[6.0]     0.9783      0.194      5.034      0.000       0.597       1.359
# x1:C(id)[7.0]     1.0370      0.198      5.227      0.000       0.648       1.426
# x1:C(id)[8.0]     0.7806      0.189      4.134      0.000       0.410       1.151
# x1:C(id)[9.0]     1.1365      0.196      5.791      0.000       0.752       1.521
# ==============================================================================
# Omnibus:                        0.504   Durbin-Watson:                   1.382
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.522
# Skew:                          -0.016   Prob(JB):                        0.770
# Kurtosis:                       2.986   Cond. No.                         3.22
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Now Incorporate Linearmodels

# %%
import linearmodels as lm

# %% [markdown]
# ## Alternative Data

# %%
# finding impact of annual salary on annual holiday spending

# logentertainment_{i,t} = beta*logsalary_{i,t} + gamma_i + gamma_t + u_{i,t}
# allow logsalary_{i,t} to relate to fixed effect so that there is bias unless fixed effects are controlled for
# for example people who take longer holidays may work less and make less money
# in this case we might have logsalary_{i,t} = -0.1*gamma_i + e_{i,t}

N = 100
T = 100
sd_gammai = 1
sd_gammat = 1
sd_e = 1
sd_u = 1
interactioncoeff = -1
beta = 1

index_i = list(range(N))
index_t = list(range(T))

# set up i dataset and t dataset
gamma_i = np.random.normal(scale=sd_gammai, size=N)
df_i = pd.DataFrame({'gamma_i': gamma_i, 'index_i': index_i})
gamma_t = np.random.normal(scale=sd_gammat, size=T)
df_t = pd.DataFrame({'gamma_t': gamma_t, 'index_t': index_t})

# set up df_it
df = pd.DataFrame(list(product(index_i, index_t)), columns = ['index_i', 'index_t'])
df = df.merge(df_i, on = 'index_i', how = 'left')
df = df.merge(df_t, on = 'index_t', how = 'left')

# add other i,t variables to df
df['e_it'] = np.random.normal(scale=sd_e, size=N*T)
df['u_it'] = np.random.normal(scale=sd_u, size=N*T)
# add interaction with fixed effect
df['logsalary_it'] = df['e_it'] + interactioncoeff * df['gamma_i']
df['logholiday_it'] = beta * df['logsalary_it'] + df['gamma_i'] + df['gamma_t'] + df['u_it']

# set index with i first and t second
dfwithoutindex = df
dfwithindex = df.set_index(['index_i', 'index_t'])

# %% [markdown]
# ## Linearmodels: OLS

# %%
model = lm.PanelOLS.from_formula('logholiday_it ~ logsalary_it', data=dfwithindex).fit()
print(model)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          logholiday_it   R-squared:                        0.1454
# Estimator:                   PanelOLS   R-squared (Between):             -10.500
# No. Observations:               10000   R-squared (Within):               0.2231
# Date:                Mon, Mar 18 2024   R-squared (Overall):              0.1454
# Time:                        14:12:20   Log-likelihood                -1.926e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1701.1
# Entities:                         100   P-value                           0.0000
# Avg Obs:                      100.000   Distribution:                  F(1,9999)
# Min Obs:                      100.000
# Max Obs:                      100.000   F-statistic (robust):             1701.1
#                                         P-value                           0.0000
# Time periods:                     100   Distribution:                  F(1,9999)
# Avg Obs:                      100.000
# Min Obs:                      100.000
# Max Obs:                      100.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# logsalary_it     0.4686     0.0114     41.244     0.0000      0.4464      0.4909
# ================================================================================

# %% [markdown]
# ## Linearmodels: OLS with Clustered Fixed Effects

# %%
model = lm.PanelOLS.from_formula('logholiday_it ~ logsalary_it + 1', data=dfwithindex).fit(cov_type='clustered', cluster_entity=True)
print(model)
# can also run with statsmodels
# only need the dropna part if I have missing observations
# this is a little different possibly due to the constant
model = smf.ols('logholiday_it ~ logsalary_it', data=dfwithoutindex).fit(cov_type='cluster', cov_kwds={'groups': dfwithoutindex[['logholiday_it', 'logsalary_it', 'index_i']].dropna()['index_i']})
print(model.summary())
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          logholiday_it   R-squared:                        0.1464
# Estimator:                   PanelOLS   R-squared (Between):             -14.109
# No. Observations:               10000   R-squared (Within):               0.2235
# Date:                Mon, Mar 18 2024   R-squared (Overall):              0.1464
# Time:                        14:13:04   Log-likelihood                -1.924e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1715.1
# Entities:                         100   P-value                           0.0000
# Avg Obs:                      100.000   Distribution:                  F(1,9998)
# Min Obs:                      100.000
# Max Obs:                      100.000   F-statistic (robust):             172.42
#                                         P-value                           0.0000
# Time periods:                     100   Distribution:                  F(1,9998)
# Avg Obs:                      100.000
# Min Obs:                      100.000
# Max Obs:                      100.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# Intercept        0.0922     0.0508     1.8145     0.0696     -0.0074      0.1918
# logsalary_it     0.4700     0.0358     13.131     0.0000      0.3998      0.5401
# ================================================================================
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          logholiday_it   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                     170.7
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):           2.85e-23
# Time:                        14:13:04   Log-Likelihood:                -19242.
# No. Observations:               10000   AIC:                         3.849e+04
# Df Residuals:                    9998   BIC:                         3.850e+04
# Df Model:                           1
# Covariance Type:              cluster
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0922      0.051      1.806      0.071      -0.008       0.192
# logsalary_it     0.4700      0.036     13.066      0.000       0.399       0.540
# ==============================================================================
# Omnibus:                       20.977   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.328
# Skew:                           0.100   Prob(JB):                     2.34e-05
# Kurtosis:                       3.106   Cond. No.                         1.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)

# %% [markdown]
# ## Linearmodels: Fixed Effects Regression

# %%
model = lm.PanelOLS.from_formula('logholiday_it ~ logsalary_it + EntityEffects', data=dfwithindex).fit()
print(model)
# can also run with statsmodels
# only need the dropna part if I have missing observations
model = smf.ols('logholiday_it ~ logsalary_it + C(index_i)', data=dfwithoutindex).fit()
print(model.summary())
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          logholiday_it   R-squared:                        0.3096
# Estimator:                   PanelOLS   R-squared (Between):             -47.597
# No. Observations:               10000   R-squared (Within):               0.3096
# Date:                Mon, Mar 18 2024   R-squared (Overall):             -0.0375
# Time:                        14:13:40   Log-likelihood                -1.815e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4439.2
# Entities:                         100   P-value                           0.0000
# Avg Obs:                      100.000   Distribution:                  F(1,9899)
# Min Obs:                      100.000
# Max Obs:                      100.000   F-statistic (robust):             4439.2
#                                         P-value                           0.0000
# Time periods:                     100   Distribution:                  F(1,9899)
# Avg Obs:                      100.000
# Min Obs:                      100.000
# Max Obs:                      100.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# logsalary_it     0.9942     0.0149     66.627     0.0000      0.9649      1.0234
# ================================================================================
#
# F-test for Poolability: 24.302
# P-value: 0.0000
# Distribution: F(99,9899)
#
# Included effects: Entity
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          logholiday_it   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     45.17
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):               0.00
# Time:                        14:13:41   Log-Likelihood:                -18154.
# No. Observations:               10000   AIC:                         3.651e+04
# Df Residuals:                    9899   BIC:                         3.724e+04
# Df Model:                         100
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.6822      0.150     -4.544      0.000      -0.976      -0.388
# C(index_i)[T.1]      1.3908      0.213      6.541      0.000       0.974       1.808
# C(index_i)[T.2]      2.0453      0.214      9.551      0.000       1.626       2.465
# C(index_i)[T.3]      2.9991      0.216     13.855      0.000       2.575       3.423
# C(index_i)[T.4]      0.7174      0.212      3.386      0.001       0.302       1.133
# C(index_i)[T.5]     -0.5579      0.211     -2.640      0.008      -0.972      -0.144
# C(index_i)[T.6]     -0.1907      0.211     -0.902      0.367      -0.605       0.224
# C(index_i)[T.7]      0.5218      0.212      2.467      0.014       0.107       0.936
# C(index_i)[T.8]     -0.3285      0.211     -1.555      0.120      -0.743       0.086
# C(index_i)[T.9]      1.0401      0.212      4.904      0.000       0.624       1.456
# C(index_i)[T.10]     0.0273      0.211      0.129      0.897      -0.387       0.442
# C(index_i)[T.11]     1.1267      0.212      5.302      0.000       0.710       1.543
# C(index_i)[T.12]     1.1928      0.213      5.609      0.000       0.776       1.610
# C(index_i)[T.13]     3.1388      0.217     14.474      0.000       2.714       3.564
# C(index_i)[T.14]     1.0935      0.212      5.148      0.000       0.677       1.510
# C(index_i)[T.15]    -1.0255      0.212     -4.848      0.000      -1.440      -0.611
# C(index_i)[T.16]     1.3024      0.213      6.125      0.000       0.886       1.719
# C(index_i)[T.17]     1.5577      0.213      7.320      0.000       1.141       1.975
# C(index_i)[T.18]     1.3883      0.212      6.538      0.000       0.972       1.804
# C(index_i)[T.19]    -1.3547      0.212     -6.397      0.000      -1.770      -0.940
# C(index_i)[T.20]    -0.8543      0.211     -4.041      0.000      -1.269      -0.440
# C(index_i)[T.21]    -0.0520      0.211     -0.246      0.806      -0.466       0.362
# C(index_i)[T.22]     0.8089      0.212      3.816      0.000       0.393       1.224
# C(index_i)[T.23]     1.3159      0.212      6.194      0.000       0.899       1.732
# C(index_i)[T.24]     0.3938      0.211      1.862      0.063      -0.021       0.808
# C(index_i)[T.25]     0.4260      0.211      2.015      0.044       0.012       0.840
# C(index_i)[T.26]     0.9472      0.212      4.469      0.000       0.532       1.363
# C(index_i)[T.27]     0.7808      0.212      3.680      0.000       0.365       1.197
# C(index_i)[T.28]     1.5009      0.213      7.042      0.000       1.083       1.919
# C(index_i)[T.29]     1.2402      0.212      5.837      0.000       0.824       1.657
# C(index_i)[T.30]     0.7748      0.212      3.657      0.000       0.360       1.190
# C(index_i)[T.31]     0.9854      0.212      4.646      0.000       0.570       1.401
# C(index_i)[T.32]    -0.0157      0.211     -0.074      0.941      -0.430       0.399
# C(index_i)[T.33]     2.3282      0.214     10.872      0.000       1.908       2.748
# C(index_i)[T.34]     0.2533      0.211      1.198      0.231      -0.161       0.668
# C(index_i)[T.35]     1.2693      0.212      5.978      0.000       0.853       1.686
# C(index_i)[T.36]    -0.3013      0.211     -1.426      0.154      -0.716       0.113
# C(index_i)[T.37]    -0.8719      0.212     -4.119      0.000      -1.287      -0.457
# C(index_i)[T.38]    -0.4688      0.211     -2.218      0.027      -0.883      -0.055
# C(index_i)[T.39]     0.0047      0.211      0.022      0.982      -0.410       0.419
# C(index_i)[T.40]     1.9769      0.214      9.249      0.000       1.558       2.396
# C(index_i)[T.41]     0.8582      0.212      4.050      0.000       0.443       1.274
# C(index_i)[T.42]    -0.1644      0.211     -0.778      0.437      -0.579       0.250
# C(index_i)[T.43]     3.2023      0.217     14.725      0.000       2.776       3.629
# C(index_i)[T.44]    -0.2607      0.211     -1.234      0.217      -0.675       0.154
# C(index_i)[T.45]     1.0632      0.212      5.017      0.000       0.648       1.479
# C(index_i)[T.46]     1.1016      0.212      5.191      0.000       0.686       1.518
# C(index_i)[T.47]     2.3206      0.214     10.832      0.000       1.901       2.741
# C(index_i)[T.48]     0.3698      0.211      1.749      0.080      -0.045       0.784
# C(index_i)[T.49]     0.1960      0.211      0.927      0.354      -0.218       0.610
# C(index_i)[T.50]    -1.0884      0.212     -5.145      0.000      -1.503      -0.674
# C(index_i)[T.51]     0.7801      0.212      3.687      0.000       0.365       1.195
# C(index_i)[T.52]     3.0589      0.216     14.144      0.000       2.635       3.483
# C(index_i)[T.53]     0.7312      0.212      3.453      0.001       0.316       1.146
# C(index_i)[T.54]     0.4857      0.212      2.295      0.022       0.071       0.900
# C(index_i)[T.55]     1.3770      0.213      6.471      0.000       0.960       1.794
# C(index_i)[T.56]     0.3897      0.212      1.842      0.065      -0.025       0.804
# C(index_i)[T.57]     1.7561      0.213      8.235      0.000       1.338       2.174
# C(index_i)[T.58]     2.5746      0.215     11.962      0.000       2.153       2.996
# C(index_i)[T.59]     1.0466      0.212      4.932      0.000       0.631       1.463
# C(index_i)[T.60]     1.6801      0.213      7.898      0.000       1.263       2.097
# C(index_i)[T.61]    -0.5008      0.211     -2.369      0.018      -0.915      -0.086
# C(index_i)[T.62]     0.6084      0.212      2.873      0.004       0.193       1.023
# C(index_i)[T.63]     0.8041      0.212      3.799      0.000       0.389       1.219
# C(index_i)[T.64]     1.4880      0.213      6.995      0.000       1.071       1.905
# C(index_i)[T.65]     0.5526      0.212      2.610      0.009       0.138       0.968
# C(index_i)[T.66]     2.0004      0.214      9.365      0.000       1.582       2.419
# C(index_i)[T.67]     0.7556      0.212      3.566      0.000       0.340       1.171
# C(index_i)[T.68]    -1.1075      0.212     -5.231      0.000      -1.522      -0.692
# C(index_i)[T.69]    -0.5397      0.211     -2.554      0.011      -0.954      -0.125
# C(index_i)[T.70]     3.0650      0.216     14.160      0.000       2.641       3.489
# C(index_i)[T.71]     0.6352      0.212      2.998      0.003       0.220       1.051
# C(index_i)[T.72]     1.9552      0.214      9.141      0.000       1.536       2.375
# C(index_i)[T.73]    -0.9099      0.212     -4.299      0.000      -1.325      -0.495
# C(index_i)[T.74]     0.3904      0.212      1.845      0.065      -0.024       0.805
# C(index_i)[T.75]    -0.1520      0.211     -0.719      0.472      -0.566       0.262
# C(index_i)[T.76]     0.0509      0.211      0.241      0.810      -0.363       0.465
# C(index_i)[T.77]    -0.1902      0.211     -0.900      0.368      -0.604       0.224
# C(index_i)[T.78]     0.7984      0.212      3.770      0.000       0.383       1.214
# C(index_i)[T.79]    -0.1540      0.211     -0.729      0.466      -0.568       0.260
# C(index_i)[T.80]     1.2767      0.213      5.997      0.000       0.859       1.694
# C(index_i)[T.81]     1.2102      0.213      5.689      0.000       0.793       1.627
# C(index_i)[T.82]     3.5566      0.220     16.199      0.000       3.126       3.987
# C(index_i)[T.83]     1.0419      0.212      4.903      0.000       0.625       1.458
# C(index_i)[T.84]     0.6222      0.212      2.938      0.003       0.207       1.037
# C(index_i)[T.85]     0.1784      0.211      0.844      0.398      -0.236       0.593
# C(index_i)[T.86]     0.6633      0.212      3.133      0.002       0.248       1.078
# C(index_i)[T.87]    -0.5181      0.211     -2.450      0.014      -0.932      -0.104
# C(index_i)[T.88]     0.8295      0.212      3.914      0.000       0.414       1.245
# C(index_i)[T.89]     1.7334      0.213      8.127      0.000       1.315       2.151
# C(index_i)[T.90]     0.2937      0.211      1.389      0.165      -0.121       0.708
# C(index_i)[T.91]     0.9792      0.212      4.622      0.000       0.564       1.394
# C(index_i)[T.92]     3.1513      0.218     14.467      0.000       2.724       3.578
# C(index_i)[T.93]    -0.1261      0.211     -0.597      0.551      -0.540       0.288
# C(index_i)[T.94]     1.7794      0.214      8.317      0.000       1.360       2.199
# C(index_i)[T.95]     1.1394      0.212      5.368      0.000       0.723       1.555
# C(index_i)[T.96]     0.6433      0.212      3.039      0.002       0.228       1.058
# C(index_i)[T.97]     1.6542      0.213      7.759      0.000       1.236       2.072
# C(index_i)[T.98]    -0.0966      0.211     -0.457      0.647      -0.511       0.318
# C(index_i)[T.99]    -0.5176      0.211     -2.449      0.014      -0.932      -0.103
# logsalary_it         0.9942      0.015     66.627      0.000       0.965       1.023
# ==============================================================================
# Omnibus:                       21.242   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.381
# Skew:                           0.107   Prob(JB):                     2.28e-05
# Kurtosis:                       3.077   Cond. No.                         148.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
## Linearmodels: Clustering on Entity/Fixed Effects

# %%
# fixed effects regression clustering on entity effects
model = lm.PanelOLS.from_formula('logholiday_it ~ logsalary_it + EntityEffects', data=dfwithindex).fit(cov_type="clustered", cluster_entity=True)
print(model)
# can also run with statsmodels
# only need the dropna part if I have missing observations
model = smf.ols('logholiday_it ~ logsalary_it + C(index_i)', data=dfwithoutindex).fit(cov_type='cluster', cov_kwds={'groups': dfwithoutindex[['logholiday_it', 'logsalary_it', 'index_i']].dropna()['index_i']})
print(model.summary())

# fixed effects regression clustering on time effects
model = lm.PanelOLS.from_formula('logholiday_it ~ logsalary_it + EntityEffects', data=dfwithindex).fit(cov_type="clustered", cluster_time=True)
print(model)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          logholiday_it   R-squared:                        0.3096
# Estimator:                   PanelOLS   R-squared (Between):             -47.597
# No. Observations:               10000   R-squared (Within):               0.3096
# Date:                Mon, Mar 18 2024   R-squared (Overall):             -0.0375
# Time:                        14:14:18   Log-likelihood                -1.815e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4439.2
# Entities:                         100   P-value                           0.0000
# Avg Obs:                      100.000   Distribution:                  F(1,9899)
# Min Obs:                      100.000
# Max Obs:                      100.000   F-statistic (robust):             5648.5
#                                         P-value                           0.0000
# Time periods:                     100   Distribution:                  F(1,9899)
# Avg Obs:                      100.000
# Min Obs:                      100.000
# Max Obs:                      100.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# logsalary_it     0.9942     0.0132     75.157     0.0000      0.9683      1.0201
# ================================================================================
#
# F-test for Poolability: 24.302
# P-value: 0.0000
# Distribution: F(99,9899)
#
# Included effects: Entity
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          logholiday_it   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     4473.
# Date:                Mon, 18 Mar 2024   Prob (F-statistic):           3.29e-84
# Time:                        14:14:18   Log-Likelihood:                -18154.
# No. Observations:               10000   AIC:                         3.651e+04
# Df Residuals:                    9899   BIC:                         3.724e+04
# Df Model:                         100
# Covariance Type:              cluster
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.6822      0.013    -52.364      0.000      -0.708      -0.657
# C(index_i)[T.1]      1.3908      0.021     65.935      0.000       1.349       1.432
# C(index_i)[T.2]      2.0453      0.031     65.717      0.000       1.984       2.106
# C(index_i)[T.3]      2.9991      0.042     71.266      0.000       2.917       3.082
# C(index_i)[T.4]      0.7174      0.014     51.451      0.000       0.690       0.745
# C(index_i)[T.5]     -0.5579      0.003   -192.317      0.000      -0.564      -0.552
# C(index_i)[T.6]     -0.1907      0.002   -124.619      0.000      -0.194      -0.188
# C(index_i)[T.7]      0.5218      0.008     62.172      0.000       0.505       0.538
# C(index_i)[T.8]     -0.3285      0.001   -439.635      0.000      -0.330      -0.327
# C(index_i)[T.9]      1.0401      0.016     63.426      0.000       1.008       1.072
# C(index_i)[T.10]     0.0273      0.002     14.402      0.000       0.024       0.031
# C(index_i)[T.11]     1.1267      0.020     55.876      0.000       1.087       1.166
# C(index_i)[T.12]     1.1928      0.021     55.698      0.000       1.151       1.235
# C(index_i)[T.13]     3.1388      0.044     71.894      0.000       3.053       3.224
# C(index_i)[T.14]     1.0935      0.019     56.139      0.000       1.055       1.132
# C(index_i)[T.15]    -1.0255      0.009   -112.145      0.000      -1.043      -1.008
# C(index_i)[T.16]     1.3024      0.021     61.220      0.000       1.261       1.344
# C(index_i)[T.17]     1.5577      0.023     68.696      0.000       1.513       1.602
# C(index_i)[T.18]     1.3883      0.019     74.257      0.000       1.352       1.425
# C(index_i)[T.19]    -1.3547      0.013   -106.149      0.000      -1.380      -1.330
# C(index_i)[T.20]    -0.8543      0.007   -125.697      0.000      -0.868      -0.841
# C(index_i)[T.21]    -0.0520      0.001    -57.500      0.000      -0.054      -0.050
# C(index_i)[T.22]     0.8089      0.015     52.933      0.000       0.779       0.839
# C(index_i)[T.23]     1.3159      0.020     67.161      0.000       1.277       1.354
# C(index_i)[T.24]     0.3938      0.006     61.776      0.000       0.381       0.406
# C(index_i)[T.25]     0.4260      0.006     69.607      0.000       0.414       0.438
# C(index_i)[T.26]     0.9472      0.015     64.733      0.000       0.919       0.976
# C(index_i)[T.27]     0.7808      0.017     45.775      0.000       0.747       0.814
# C(index_i)[T.28]     1.5009      0.025     60.275      0.000       1.452       1.550
# C(index_i)[T.29]     1.2402      0.020     62.392      0.000       1.201       1.279
# C(index_i)[T.30]     0.7748      0.014     56.767      0.000       0.748       0.802
# C(index_i)[T.31]     0.9854      0.016     60.403      0.000       0.953       1.017
# C(index_i)[T.32]    -0.0157      0.003     -4.490      0.000      -0.023      -0.009
# C(index_i)[T.33]     2.3282      0.031     74.792      0.000       2.267       2.389
# C(index_i)[T.34]     0.2533      0.006     45.296      0.000       0.242       0.264
# C(index_i)[T.35]     1.2693      0.019     68.205      0.000       1.233       1.306
# C(index_i)[T.36]    -0.3013      0.000   -829.404      0.000      -0.302      -0.301
# C(index_i)[T.37]    -0.8719      0.011    -79.194      0.000      -0.893      -0.850
# C(index_i)[T.38]    -0.4688      0.002   -301.501      0.000      -0.472      -0.466
# C(index_i)[T.39]     0.0047      0.002      2.245      0.025       0.001       0.009
# C(index_i)[T.40]     1.9769      0.029     68.442      0.000       1.920       2.034
# C(index_i)[T.41]     0.8582      0.014     60.493      0.000       0.830       0.886
# C(index_i)[T.42]    -0.1644      0.002    -87.506      0.000      -0.168      -0.161
# C(index_i)[T.43]     3.2023      0.046     69.491      0.000       3.112       3.293
# C(index_i)[T.44]    -0.2607      0.002   -111.451      0.000      -0.265      -0.256
# C(index_i)[T.45]     1.0632      0.014     74.367      0.000       1.035       1.091
# C(index_i)[T.46]     1.1016      0.018     62.105      0.000       1.067       1.136
# C(index_i)[T.47]     2.3206      0.032     73.269      0.000       2.259       2.383
# C(index_i)[T.48]     0.3698      0.006     60.383      0.000       0.358       0.382
# C(index_i)[T.49]     0.1960      0.006     32.385      0.000       0.184       0.208
# C(index_i)[T.50]    -1.0884      0.009   -117.763      0.000      -1.107      -1.070
# C(index_i)[T.51]     0.7801      0.010     76.513      0.000       0.760       0.800
# C(index_i)[T.52]     3.0589      0.041     74.164      0.000       2.978       3.140
# C(index_i)[T.53]     0.7312      0.012     59.963      0.000       0.707       0.755
# C(index_i)[T.54]     0.4857      0.010     48.156      0.000       0.466       0.505
# C(index_i)[T.55]     1.3770      0.023     60.987      0.000       1.333       1.421
# C(index_i)[T.56]     0.3897      0.009     44.994      0.000       0.373       0.407
# C(index_i)[T.57]     1.7561      0.026     68.225      0.000       1.706       1.806
# C(index_i)[T.58]     2.5746      0.037     70.194      0.000       2.503       2.646
# C(index_i)[T.59]     1.0466      0.017     60.308      0.000       1.013       1.081
# C(index_i)[T.60]     1.6801      0.022     76.446      0.000       1.637       1.723
# C(index_i)[T.61]    -0.5008      0.007    -68.493      0.000      -0.515      -0.487
# C(index_i)[T.62]     0.6084      0.012     48.704      0.000       0.584       0.633
# C(index_i)[T.63]     0.8041      0.011     75.200      0.000       0.783       0.825
# C(index_i)[T.64]     1.4880      0.022     67.981      0.000       1.445       1.531
# C(index_i)[T.65]     0.5526      0.012     47.576      0.000       0.530       0.575
# C(index_i)[T.66]     2.0004      0.028     71.276      0.000       1.945       2.055
# C(index_i)[T.67]     0.7556      0.014     53.503      0.000       0.728       0.783
# C(index_i)[T.68]    -1.1075      0.012    -93.103      0.000      -1.131      -1.084
# C(index_i)[T.69]    -0.5397      0.004   -142.825      0.000      -0.547      -0.532
# C(index_i)[T.70]     3.0650      0.042     72.920      0.000       2.983       3.147
# C(index_i)[T.71]     0.6352      0.014     44.919      0.000       0.607       0.663
# C(index_i)[T.72]     1.9552      0.030     65.700      0.000       1.897       2.014
# C(index_i)[T.73]    -0.9099      0.010    -86.684      0.000      -0.930      -0.889
# C(index_i)[T.74]     0.3904      0.010     40.424      0.000       0.371       0.409
# C(index_i)[T.75]    -0.1520      0.002    -93.645      0.000      -0.155      -0.149
# C(index_i)[T.76]     0.0509      0.003     15.132      0.000       0.044       0.057
# C(index_i)[T.77]    -0.1902      0.000   -464.496      0.000      -0.191      -0.189
# C(index_i)[T.78]     0.7984      0.013     62.599      0.000       0.773       0.823
# C(index_i)[T.79]    -0.1540      0.000   -596.276      0.000      -0.154      -0.153
# C(index_i)[T.80]     1.2767      0.023     55.071      0.000       1.231       1.322
# C(index_i)[T.81]     1.2102      0.022     54.808      0.000       1.167       1.253
# C(index_i)[T.82]     3.5566      0.053     66.612      0.000       3.452       3.661
# C(index_i)[T.83]     1.0419      0.020     51.658      0.000       1.002       1.081
# C(index_i)[T.84]     0.6222      0.012     50.671      0.000       0.598       0.646
# C(index_i)[T.85]     0.1784      0.002     93.922      0.000       0.175       0.182
# C(index_i)[T.86]     0.6633      0.012     55.018      0.000       0.640       0.687
# C(index_i)[T.87]    -0.5181      0.006    -81.356      0.000      -0.531      -0.506
# C(index_i)[T.88]     0.8295      0.015     56.766      0.000       0.801       0.858
# C(index_i)[T.89]     1.7334      0.026     66.847      0.000       1.683       1.784
# C(index_i)[T.90]     0.2937      0.006     47.095      0.000       0.282       0.306
# C(index_i)[T.91]     0.9792      0.014     71.767      0.000       0.952       1.006
# C(index_i)[T.92]     3.1513      0.047     66.471      0.000       3.058       3.244
# C(index_i)[T.93]    -0.1261      0.001   -115.572      0.000      -0.128      -0.124
# C(index_i)[T.94]     1.7794      0.030     59.302      0.000       1.721       1.838
# C(index_i)[T.95]     1.1394      0.018     62.712      0.000       1.104       1.175
# C(index_i)[T.96]     0.6433      0.011     58.346      0.000       0.622       0.665
# C(index_i)[T.97]     1.6542      0.025     64.997      0.000       1.604       1.704
# C(index_i)[T.98]    -0.0966      0.004    -26.604      0.000      -0.104      -0.090
# C(index_i)[T.99]    -0.5176      0.003   -166.456      0.000      -0.524      -0.512
# logsalary_it         0.9942      0.013     74.409      0.000       0.968       1.020
# ==============================================================================
# Omnibus:                       21.242   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.381
# Skew:                           0.107   Prob(JB):                     2.28e-05
# Kurtosis:                       3.077   Cond. No.                         148.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          logholiday_it   R-squared:                        0.3096
# Estimator:                   PanelOLS   R-squared (Between):             -47.597
# No. Observations:               10000   R-squared (Within):               0.3096
# Date:                Mon, Mar 18 2024   R-squared (Overall):             -0.0375
# Time:                        14:14:18   Log-likelihood                -1.815e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4439.2
# Entities:                         100   P-value                           0.0000
# Avg Obs:                      100.000   Distribution:                  F(1,9899)
# Min Obs:                      100.000
# Max Obs:                      100.000   F-statistic (robust):             4878.0
#                                         P-value                           0.0000
# Time periods:                     100   Distribution:                  F(1,9899)
# Avg Obs:                      100.000
# Min Obs:                      100.000
# Max Obs:                      100.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# logsalary_it     0.9942     0.0142     69.843     0.0000      0.9663      1.0221
# ================================================================================
#
# F-test for Poolability: 24.302
# P-value: 0.0000
# Distribution: F(99,9899)
#
# Included effects: Entity
# /shared/venvs/cdc-mdc2/lib/python3.8/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 100, but rank is 1
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ## Linearmodels: Including Entity and Time Fixed Effects

# %%
model = lm.PanelOLS.from_formula('logholiday_it ~ logsalary_it + EntityEffects + TimeEffects', data=dfwithindex).fit()
print(model)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          logholiday_it   R-squared:                        0.4933
# Estimator:                   PanelOLS   R-squared (Between):             -46.822
# No. Observations:               10000   R-squared (Within):               0.3096
# Date:                Mon, Mar 18 2024   R-squared (Overall):             -0.0319
# Time:                        14:15:34   Log-likelihood                -1.414e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      9541.6
# Entities:                         100   P-value                           0.0000
# Avg Obs:                      100.000   Distribution:                  F(1,9800)
# Min Obs:                      100.000
# Max Obs:                      100.000   F-statistic (robust):             9541.6
#                                         P-value                           0.0000
# Time periods:                     100   Distribution:                  F(1,9800)
# Avg Obs:                      100.000
# Min Obs:                      100.000
# Max Obs:                      100.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# logsalary_it     0.9861     0.0101     97.681     0.0000      0.9663      1.0059
# ================================================================================
#
# F-test for Poolability: 87.728
# P-value: 0.0000
# Distribution: F(198,9800)
#
# Included effects: Entity, Time

# %%
# basic ols
model0 = lm.PanelOLS.from_formula('logholiday_it ~ logsalary_it', data=dfwithindex).fit()

# fixed effects regression
model1 = lm.PanelOLS.from_formula('logholiday_it ~ logsalary_it + EntityEffects', data=dfwithindex).fit()

# fixed effects + time fixed effects regression
model2 = lm.PanelOLS.from_formula('logholiday_it ~ logsalary_it + EntityEffects + TimeEffects', data=dfwithindex).fit()

models = [model0, model1, model2]
tabular = getsmresultstable(models, printtab = True, savename = None, ynames = ['', 'Pooled OLS', 'Fixed', 'Fixed + Time'], coefflist = None, coeffnames = None)
# Out:
#              Pooled OLS Fixed    Fixed + Time
# logsalary_it 0.469***   0.994*** 0.986***
#              (0.011)    (0.015)  (0.010)
# N            10000      10000    10000
# $R^2$        0.145      0.310    0.493
